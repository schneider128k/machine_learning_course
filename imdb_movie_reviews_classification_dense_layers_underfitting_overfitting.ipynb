# %% [markdown]
# <a href="https://colab.research.google.com/github/schneider128k/machine_learning_course/blob/master/imdb_movie_reviews_classification_dense_layers_underfitting_overfitting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # IMBD movie reviews dataset

# %% [markdown]
# ## Loading the IMBD dataset

# %%
# %tensorflow_version 2.x
import tensorflow as tf

(train_data, train_labels), (test_data, test_labels) = tf.keras.datasets.imdb.load_data(num_words=10000)
# Out:
# TensorFlow 2.x selected.
# ...
# 17465344/17464789 [==============================] - 0s 0us/step

# %% [markdown]
# See [https://keras.io/datasets/#imdb-movie-reviews-sentiment-classification](https://keras.io/datasets/#imdb-movie-reviews-sentiment-classification) for all more details.

# %% [markdown]
# ## Preparing the data

# %%
import numpy as np

def vectorize_sequences(sequences, dimension=10000):
    results = np.zeros((len(sequences), dimension))
    for i, sequence in enumerate(sequences):
        results[i, sequence] = 1.0
    return results

x_train = vectorize_sequences(train_data)
x_test = vectorize_sequences(test_data)

y_train = np.asarray(train_labels).astype('float32')
y_test = np.asarray(test_labels).astype('float32')

# %% [markdown]
# ## Create validation set

# %%
x_val = x_train[:10000]
partial_x_train = x_train[10000:]

y_val = y_train[:10000]
partial_y_train = y_train[10000:]

# %% [markdown]
# ## Build, compile, train, and analyze models

# %%
def build_model(sizes):
    model = tf.keras.models.Sequential()
    model.add(tf.keras.layers.Input(shape=(10000)))
    
    for size in sizes:
        model.add(tf.keras.layers.Dense(size, activation='relu'))
    
    model.add(tf.keras.layers.Dense(1, activation='sigmoid'))

    return model

# %%
# original model
model_0 = build_model([16, 16])

# lower capacity
model_1 = build_model([4, 4])

# higher capacity
model_2 = build_model([512, 512])

models = [model_0, model_1, model_2]

# %%
def compile_model(model):
    model.compile(optimizer=tf.keras.optimizers.RMSprop(lr=0.001),
                  loss='binary_crossentropy',
                  metrics=['accuracy'])

# %%
for model in models:
    compile_model(model)

# %%
def fit_model(model):
    history = model.fit(partial_x_train,
                        partial_y_train,
                        epochs=20,
                        batch_size=512,
                        verbose=0,
                        validation_data=(x_val, y_val))
    return history

# %%
histories = [] 
for model in models:
    histories.append(fit_model(model))

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import (AutoMinorLocator, MultipleLocator)

def show_learning_curves(history, i):
    pd.DataFrame(history.history).plot(figsize=(10, 5))
    plt.title(f'model {i}')
    plt.grid(True)

    plt.gca().set_ylim(0, 1.1) 
    plt.gca().set_xlim(0, 19)

    plt.gca().xaxis.set_major_locator(MultipleLocator(2))

    plt.gca().xaxis.set_major_formatter(plt.FuncFormatter(lambda x, _ : int(x + 1)))

    plt.gca().xaxis.set_minor_locator(AutoMinorLocator(2))
    plt.gca().grid(which='minor', color='#CCCCCC', linestyle='--')

    plt.show()

# %%
for i, history in enumerate(histories):
    show_learning_curves(history, i)

# %% [markdown]
# The smaller network ```model_1``` starts overfitting later than the reference network, and its performance degrades more slowly one it starts overfitting.
#
# The bigger network ```model_2``` starts overfitting almost immediately, and it overfits much more severely. Its validation loss is also noisier.
#
# Look at the training/validation losses/accuracies.
